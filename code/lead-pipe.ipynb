# %%
import pandas as pd
import numpy as np
from sodapy import Socrata

# %%
# https://data.cityofnewyork.us/resource/pfvg-hyrc.json

# %% [markdown]
# #### Token info

# %%
MyAppToken = "q1CBbdd2qgBeX7djvaE7muKIZ"
userame = "minhanh0604@gmail.com"
password = "R$@GzqVH5#RpWW6"

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofnewyork.us",
                  MyAppToken,
                  userame,
                  password,
                  timeout = 600)

# %%
data_id = "pfvg-hyrc"

# limit = number of first results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get(data_id, limit = 1000000, offset = 0)

# %%
# Convert to pandas DataFrame
df = pd.DataFrame.from_records(results)

df
# Out:
#                                                  the_geom objectid_1  \
# 0       {'type': 'MultiPolygon', 'coordinates': [[[[-7...          1
# 1       {'type': 'MultiPolygon', 'coordinates': [[[[-7...          2
# 2       {'type': 'MultiPolygon', 'coordinates': [[[[-7...          3
# 3       {'type': 'MultiPolygon', 'coordinates': [[[[-7...          4
# 4       {'type': 'MultiPolygon', 'coordinates': [[[[-7...          5
# ...                                                   ...        ...
# 857531  {'type': 'MultiPolygon', 'coordinates': [[[[-7...     857532
# 857532  {'type': 'MultiPolygon', 'coordinates': [[[[-7...     857533
# 857533  {'type': 'MultiPolygon', 'coordinates': [[[[-7...     857534
# 857534  {'type': 'MultiPolygon', 'coordinates': [[[[-7...     857535
# 857535  {'type': 'MultiPolygon', 'coordinates': [[[[-7...     857536
#
#               tbbl             address        material       record_typ  \
# ...

# %% [markdown]
# #### Save data as CSV

# %%
df.to_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/data/Lead Pipes/lead_pipes_citywide.csv')

# %% [markdown]
# #### Potential Lead filter

# %%
potential_lead = df['material'].str.contains('Potential Lead', na = False)

df_potential_lead = df.loc[potential_lead]

df_potential_lead
# Out:
#                                                  the_geom objectid_1  \
# 18      {'type': 'MultiPolygon', 'coordinates': [[[[-7...         19
# 21      {'type': 'MultiPolygon', 'coordinates': [[[[-7...         22
# 22      {'type': 'MultiPolygon', 'coordinates': [[[[-7...         23
# 30      {'type': 'MultiPolygon', 'coordinates': [[[[-7...         31
# 37      {'type': 'MultiPolygon', 'coordinates': [[[[-7...         38
# ...                                                   ...        ...
# 857504  {'type': 'MultiPolygon', 'coordinates': [[[[-7...     857505
# 857505  {'type': 'MultiPolygon', 'coordinates': [[[[-7...     857506
# 857528  {'type': 'MultiPolygon', 'coordinates': [[[[-7...     857529
# 857531  {'type': 'MultiPolygon', 'coordinates': [[[[-7...     857532
# 857533  {'type': 'MultiPolygon', 'coordinates': [[[[-7...     857534
#
#               tbbl              address        material       record_typ  \
# ...

# %% [markdown]
# #### Lower East Side with Potential Lead materials

# %%
df_potential_lead.to_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/data/Lead Pipes/lead_pipes_potential_lead.csv')

# %%
df_lowereast = pd.read_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/data/Lead Pipes/lead_pipes_potential_lead.csv')

df_lowereast
# Out:
#         Unnamed: 0                                           the_geom  \
# 0               18  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 1               21  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 2               22  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 3               30  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 4               37  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# ...            ...                                                ...
# 135991      857504  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 135992      857505  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 135993      857528  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 135994      857531  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 135995      857533  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
#
#         objectid_1        tbbl              address        material  \
# ...

# %%
#df_lowereast = df[df['address'].isin(['allen street', 'EAST HOUSTON STREET', 'ESSEX STREET', 'CANAL STREET', 'ELDRIDGE STREET', 'EAST Broadway', 'GRAND STREET'])]

df_lowereast['address'] = df_lowereast['address'].astype('string')

df_lowereast.dtypes
# Out:
# Unnamed: 0      int64
# the_geom       object
# objectid_1      int64
# tbbl            int64
# address        string
# material       object
# record_typ     object
# city_owned     object
# shape_leng    float64
# shape_area    float64
# dtype: object

# %%
st_lowerest = ['ALLEN STREET', 'EAST HOUSTON STREET', 'ESSEX STREET', 'CANAL STREET', 'ELDRIDGE STREET', 'EAST Broadway', 'GRAND STREET']

df_lowereast = df_lowereast[df_lowereast['address'].str.contains('|'.join(st_lowerest))]

df_lowereast
# Out:
#         Unnamed: 0                                           the_geom  \
# 15             368  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 16             372  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 25             434  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 26             435  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 27             436  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# ...            ...                                                ...
# 131551      750882  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 131552      750887  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 131553      750889  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 131554      750891  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 131555      750894  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
#
#         objectid_1        tbbl           address        material  \
# ...

# %%
df_lowereast.to_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/data/Lead Pipes/lead_pipes_lowereast.csv')

# %% [markdown]
# #### East Harlem with Potential Lead

# %%
df_eastharlem = pd.read_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/data/Lead Pipes/lead_pipes_potential_lead.csv')

df_eastharlem
# Out:
#         Unnamed: 0                                           the_geom  \
# 0               18  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 1               21  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 2               22  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 3               30  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 4               37  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# ...            ...                                                ...
# 135991      857504  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 135992      857505  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 135993      857528  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 135994      857531  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 135995      857533  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
#
#         objectid_1        tbbl              address        material  \
# ...

# %%
df_eastharlem['address'] = df_eastharlem['address'].astype('string')

df_eastharlem.dtypes
# Out:
# Unnamed: 0      int64
# the_geom       object
# objectid_1      int64
# tbbl            int64
# address        string
# material       object
# record_typ     object
# city_owned     object
# shape_leng    float64
# shape_area    float64
# dtype: object

# %%
st_eastharlem = ['EAST 96 STREET', 'EAST 97 STREET', 'EAST 98 STREET', 'EAST 99 STREET', 'EAST 100 STREET', 'EAST 110 STREET', 'EAST 112 STREET', 'EAST 113 STREET', 'EAST 114 STREET', 'EAST 115 STREET', 'EAST 116 STREET', 'EAST 117 STREET', 'EAST 118 STREET', 'EAST 119 STREET', 'EAST 120 STREET', 'EAST 121 STREET', 'EAST 122 STREET', 'EAST 123 STREET', 'EAST 124 STREET', 'EAST 125 STREET']

df_eastharlem = df_eastharlem[df_eastharlem['address'].str.contains('|'.join(st_eastharlem))]

df_eastharlem
# Out:
#        Unnamed: 0                                           the_geom  \
# 3414        24699  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 3675        26380  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 3676        26382  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 3677        26383  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 3678        26388  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# ...           ...                                                ...
# 61055      392785  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 61056      392786  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 61057      392787  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 61058      392792  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 61060      392841  {'type': 'MultiPolygon', 'coordinates': [[[[-7...
#
#        objectid_1        tbbl              address        material  \
# 3414        30580  1017100043  414 EAST 117 STREET  Potential Lead
# ...

# %%
df_eastharlem.to_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/data/Lead Pipes/lead_pipes_eastharlem.csv')
