# %%
# https://data.cityofnewyork.us/Environment/Free-Residential-at-the-tap-Lead-and-Copper-Data/k5us-nav4

# %%
import pandas as pd
import numpy as np
from sodapy import Socrata

# %% [markdown]
# #### Token info

# %%
MyAppToken = "q1CBbdd2qgBeX7djvaE7muKIZ"
userame = "minhanh0604@gmail.com"
password = "R$@GzqVH5#RpWW6"

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofnewyork.us",
                  MyAppToken,
                  userame,
                  password,
                  timeout = 600)

# %% [markdown]
# API ID

# %%
# https://data.cityofnewyork.us/resource/k5us-nav4.json

data_id = "k5us-nav4"

# limit = number of first results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get(data_id, limit = 300000, offset = 0)

# %% [markdown]
# #### Pandas data frame

# %%
# Convert to pandas DataFrame
df = pd.DataFrame.from_records(results)

df
# Out:
#          kit_id           borough zipcode           date_collected  \
# 0      13220181          NEW YORK   10128  2014-01-01T00:00:00.000
# 1      13300298          BROOKLYN   11205  2014-01-01T00:00:00.000
# 2      13300297          BROOKLYN   11205  2014-01-01T00:00:00.000
# 3      13219471          NEW YORK   10028  2014-01-01T00:00:00.000
# 4      11211471  LONG ISLAND CITY   11101  2014-01-01T00:00:00.000
# ...         ...               ...     ...                      ...
# 26108  21285539          Brooklyn   11215  2021-12-31T07:52:00.000
# 26109  21285647     Staten Island   10304  2021-12-31T09:02:00.000
# 26110  21279316          Brooklyn   11222  2021-12-31T12:15:00.000
# 26111  20271154          Brooklyn   11210  2021-12-31T13:09:00.000
# 26112  21285639          Brooklyn   11215  2021-12-31T13:41:00.000
#
#                  date_received lead_first_draw_mg_l  \
# 0      2014-01-08T00:00:00.000                    0
# 1      2014-01-08T00:00:00.000                    0
# ...

# %% [markdown]
# ### Convert value from object to float

# %%
df["lead_first_draw_mg_l"] = df["lead_first_draw_mg_l"].astype(str).astype(float)

df.lead_first_draw_mg_l.dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Filter only dangerous lead level above 15 µg/L

# %%
tap_lead = ['lead_first_draw_mg_l']
df[tap_lead] = df[df[tap_lead] > 15.00][tap_lead]

df = df.dropna()

df
# Out:
#          kit_id   borough zipcode           date_collected  \
# 14545  17343744  NEW YORK   10003  2018-08-11T00:00:00.000
#
#                  date_received  lead_first_draw_mg_l  \
# 14545  2018-08-16T00:00:00.000                15.082
#
#       lead_1_2_minute_flush_mg_l copper_first_draw_mg_l  \
# 14545                      0.046                  0.539
#
#       copper_1_2_minute_flush_mg_l lead_5_minute_flush_mg_l  \
# 14545                        0.019                    0.022
#
#       copper_5_minute_flush_mg_l
# 14545                      0.011
