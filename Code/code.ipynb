# %% [markdown]
# #### Pakages and Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Library from NYC OPEN API

# %%
from sodapy import Socrata

# %% [markdown]
# #### Request API

# %%
MyAppToken = "q1CBbdd2qgBeX7djvaE7muKIZ"
userame = "minhanh0604@gmail.com"
password = "R$@GzqVH5#RpWW6"

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofnewyork.us",
                  MyAppToken,
                  userame,
                  password,
                  timeout = 600)

# %%
# https://data.cityofnewyork.us/resource/erm2-nwe9.json

data_id = "erm2-nwe9"

# limit = number of first results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get(data_id, limit = 100000, offset = 0)

# %%
# Convert to pandas DataFrame
df = pd.DataFrame.from_records(results)

# %%
df
# Out:
#       unique_key             created_date agency  \
# 0       54061329  2022-05-02T02:19:18.000    DOT
# 1       54054340  2022-05-02T02:18:06.000    DOT
# 2       54058396  2022-05-02T02:17:03.000    DOT
# 3       54057486  2022-05-02T02:05:43.000   NYPD
# 4       54060703  2022-05-02T02:05:36.000   NYPD
# ...          ...                      ...    ...
# 99995   53956082  2022-04-19T12:52:53.000    DOB
# 99996   53956986  2022-04-19T12:52:31.000    HPD
# 99997   53957094  2022-04-19T12:52:29.000    HPD
# 99998   53957151  2022-04-19T12:52:29.000    HPD
# 99999   53955237  2022-04-19T12:52:14.000   DSNY
#
#                                              agency_name  \
# 0                           Department of Transportation
# 1                           Department of Transportation
# 2                           Department of Transportation
# 3                        New York City Police Department
# 4                        New York City Police Department
# ...                                                  ...
# 99995                            Department of Buildings
# 99996  Department of Housing Preservation and Develop...
# 99997  Department of Housing Preservation and Develop...
# 99998  Department of Housing Preservation and Develop...
# 99999                           Department of Sanitation
#
#              complaint_type                               descriptor  \
# 0          Street Condition                                  Pothole
# 1          Street Condition                                  Pothole
# 2          Street Condition                                  Pothole
# 3         Illegal Fireworks                                      N/A
# 4           Illegal Parking                        Blocked Crosswalk
# ...                     ...                                      ...
# 99995              Elevator  Elevator - Multiple Devices On Property
# 99996        HEAT/HOT WATER                          ENTIRE BUILDING
# 99997         PAINT/PLASTER                                     WALL
# 99998  UNSANITARY CONDITION                                    PESTS
# 99999       Illegal Dumping                          Removal Request
#
#       incident_zip      incident_address       street_name  \
# 0            11213  839 EMPIRE BOULEVARD  EMPIRE BOULEVARD
# 1            11225      417 MAPLE STREET      MAPLE STREET
# 2            11213     1669 UNION STREET      UNION STREET
# 3            11372               37 ROAD           37 ROAD
# 4            11103       44-03 31 AVENUE         31 AVENUE
# ...            ...                   ...               ...
# 99995        10019   25 WEST   56 STREET  WEST   56 STREET
# 99996        11102       25-54 12 STREET         12 STREET
# 99997        10314         170 ADA DRIVE         ADA DRIVE
# 99998        10314         170 ADA DRIVE         ADA DRIVE
# 99999        11236  603 EAST   94 STREET  EAST   94 STREET
#
#            cross_street_1  ...          landmark bridge_highway_name  \
# 0      SCHENECTADY AVENUE  ...               NaN                 NaN
# 1             MIAMI COURT  ...               NaN                 NaN
# 2      SCHENECTADY AVENUE  ...               NaN                 NaN
# 3                 37 ROAD  ...               NaN                 NaN
# 4               44 STREET  ...         31 AVENUE                 NaN
# ...                   ...  ...               ...                 ...
# 99995                 NaN  ...               NaN                 NaN
# 99996                 NaN  ...               NaN                 NaN
# 99997                 NaN  ...               NaN                 NaN
# 99998                 NaN  ...               NaN                 NaN
# 99999            AVENUE A  ...  EAST   94 STREET                 NaN
#
#       road_ramp bridge_highway_segment              closed_date  \
# 0           NaN                    NaN                      NaN
# 1           NaN                    NaN                      NaN
# 2           NaN                    NaN                      NaN
# 3           NaN                    NaN                      NaN
# 4           NaN                    NaN                      NaN
# ...         ...                    ...                      ...
# 99995       NaN                    NaN  2022-04-20T00:00:00.000
# 99996       NaN                    NaN  2022-04-19T18:22:18.000
# 99997       NaN                    NaN  2022-04-21T16:00:22.000
# 99998       NaN                    NaN  2022-04-21T16:00:22.000
# 99999       NaN                    NaN  2022-04-21T15:45:23.000
#
#       taxi_pick_up_location bridge_highway_direction due_date  \
# 0                       NaN                      NaN      NaN
# 1                       NaN                      NaN      NaN
# 2                       NaN                      NaN      NaN
# 3                       NaN                      NaN      NaN
# 4                       NaN                      NaN      NaN
# ...                     ...                      ...      ...
# 99995                   NaN                      NaN      NaN
# 99996                   NaN                      NaN      NaN
# 99997                   NaN                      NaN      NaN
# 99998                   NaN                      NaN      NaN
# 99999                   NaN                      NaN      NaN
#
#       taxi_company_borough vehicle_type
# 0                      NaN          NaN
# 1                      NaN          NaN
# 2                      NaN          NaN
# 3                      NaN          NaN
# 4                      NaN          NaN
# ...                    ...          ...
# 99995                  NaN          NaN
# 99996                  NaN          NaN
# 99997                  NaN          NaN
# 99998                  NaN          NaN
# 99999                  NaN          NaN
#
# [100000 rows x 46 columns]

# %% [markdown]
# ### Create filter

# %%
filter = df['complaint_type'].str.contains('Lead', na = False)
df.loc[filter]
# Out:
#       unique_key             created_date agency  \
# 666     54054716  2022-05-01T23:52:00.000    DEP
# 758     54055737  2022-05-01T23:40:00.000    DEP
# 891     54058739  2022-05-01T23:22:00.000    DEP
# 1069    54056750  2022-05-01T22:55:00.000    DEP
# 1397    54054717  2022-05-01T22:16:00.000    DEP
# ...          ...                      ...    ...
# 98896   53955344  2022-04-19T15:21:00.000    DEP
# 99564   53955345  2022-04-19T13:46:00.000    DEP
# 99675   53954123  2022-04-19T13:34:00.000    DEP
# 99680   53950701  2022-04-19T13:33:00.000    DEP
# 99772   53950702  2022-04-19T13:24:00.000    DEP
#
#                                   agency_name complaint_type  \
# 666    Department of Environmental Protection           Lead
# 758    Department of Environmental Protection           Lead
# 891    Department of Environmental Protection           Lead
# 1069   Department of Environmental Protection           Lead
# 1397   Department of Environmental Protection           Lead
# ...                                       ...            ...
# 98896  Department of Environmental Protection           Lead
# 99564  Department of Environmental Protection           Lead
# 99675  Department of Environmental Protection           Lead
# 99680  Department of Environmental Protection           Lead
# 99772  Department of Environmental Protection           Lead
#
#                                  descriptor incident_zip  \
# 666    Lead Kit Request (Residential) (L10)        10036
# 758    Lead Kit Request (Residential) (L10)        11104
# 891    Lead Kit Request (Residential) (L10)        11211
# 1069   Lead Kit Request (Residential) (L10)        10013
# 1397   Lead Kit Request (Residential) (L10)        11216
# ...                                     ...          ...
# 98896  Lead Kit Request (Residential) (L10)        11222
# 99564  Lead Kit Request (Residential) (L10)        11235
# 99675  Lead Kit Request (Residential) (L10)        11216
# 99680  Lead Kit Request (Residential) (L10)        11226
# 99772  Lead Kit Request (Residential) (L10)        11361
#
#             incident_address        street_name cross_street_1  ... landmark  \
# 666     450 WEST   47 STREET   WEST   47 STREET          9 AVE  ...      NaN
# 758          45-35 44 STREET          44 STREET    QUEENS BLVD  ...      NaN
# 891     76 RICHARDSON STREET  RICHARDSON STREET     LORIMER ST  ...      NaN
# 1069         162 MOTT STREET        MOTT STREET       GRAND ST  ...      NaN
# 1397     309 TOMPKINS AVENUE    TOMPKINS AVENUE      QUINCY ST  ...      NaN
# ...                      ...                ...            ...  ...      ...
# 98896      56 ECKFORD STREET     ECKFORD STREET     ENGERT AVE  ...      NaN
# 99564  2465 EAST   13 STREET   EAST   13 STREET       AVENUE X  ...      NaN
# 99675         845 PARK PLACE         PARK PLACE   NOSTRAND AVE  ...      NaN
# 99680   356 EAST   22 STREET   EAST   22 STREET   CORTELYOU RD  ...      NaN
# 99772       40-05 208 STREET         208 STREET       DEAD END  ...      NaN
#
#       bridge_highway_name road_ramp bridge_highway_segment  \
# 666                   NaN       NaN                    NaN
# 758                   NaN       NaN                    NaN
# 891                   NaN       NaN                    NaN
# 1069                  NaN       NaN                    NaN
# 1397                  NaN       NaN                    NaN
# ...                   ...       ...                    ...
# 98896                 NaN       NaN                    NaN
# 99564                 NaN       NaN                    NaN
# 99675                 NaN       NaN                    NaN
# 99680                 NaN       NaN                    NaN
# 99772                 NaN       NaN                    NaN
#
#                    closed_date taxi_pick_up_location bridge_highway_direction  \
# 666                        NaN                   NaN                      NaN
# 758                        NaN                   NaN                      NaN
# 891                        NaN                   NaN                      NaN
# 1069                       NaN                   NaN                      NaN
# 1397                       NaN                   NaN                      NaN
# ...                        ...                   ...                      ...
# 98896  2022-04-20T09:47:00.000                   NaN                      NaN
# 99564  2022-04-20T09:47:00.000                   NaN                      NaN
# 99675  2022-04-20T09:47:00.000                   NaN                      NaN
# 99680  2022-04-20T09:47:00.000                   NaN                      NaN
# 99772  2022-04-20T09:47:00.000                   NaN                      NaN
#
#       due_date taxi_company_borough vehicle_type
# 666        NaN                  NaN          NaN
# 758        NaN                  NaN          NaN
# 891        NaN                  NaN          NaN
# 1069       NaN                  NaN          NaN
# 1397       NaN                  NaN          NaN
# ...        ...                  ...          ...
# 98896      NaN                  NaN          NaN
# 99564      NaN                  NaN          NaN
# 99675      NaN                  NaN          NaN
# 99680      NaN                  NaN          NaN
# 99772      NaN                  NaN          NaN
#
# [258 rows x 46 columns]
