# %% [markdown]
# #### Pakages and Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Library from NYC OPEN API

# %%
from sodapy import Socrata

# %% [markdown]
# #### Request API

# %%
MyAppToken = "q1CBbdd2qgBeX7djvaE7muKIZ"
userame = "minhanh0604@gmail.com"
password = "R$@GzqVH5#RpWW6"

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofnewyork.us",
                  MyAppToken,
                  userame,
                  password,
                  timeout = 600)

# %%
# https://data.cityofnewyork.us/resource/erm2-nwe9.json

data_id = "erm2-nwe9"

# limit = number of first results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get(data_id, limit = 1000000, offset = 0)

# %%
# Convert to pandas DataFrame
df = pd.DataFrame.from_records(results)

# %%
df
# Out:
#        unique_key             created_date agency  \
# 0        54064473  2022-05-03T02:06:33.000   NYPD
# 1        54068756  2022-05-03T02:06:30.000   NYPD
# 2        54068755  2022-05-03T02:04:31.000   NYPD
# 3        54064363  2022-05-03T02:02:53.000   NYPD
# 4        54068548  2022-05-03T02:02:52.000   NYPD
# ...           ...                      ...    ...
# 999995   52875305  2021-12-23T15:33:03.000    HPD
# 999996   52877331  2021-12-23T15:33:00.000    HPD
# 999997   52878219  2021-12-23T15:32:59.000    HPD
# 999998   52881079  2021-12-23T15:32:58.000    HPD
# 999999   52878345  2021-12-23T15:32:57.000    HPD
#
#                                               agency_name  \
# 0                         New York City Police Department
# 1                         New York City Police Department
# 2                         New York City Police Department
# 3                         New York City Police Department
# 4                         New York City Police Department
# ...

# %% [markdown]
# #### Save as CSV

# %%
df.to_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/Data/exported_data.csv')

# %% [markdown]
# #### Load saved csv data as df1

# %%
df1 = pd.read_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/Data/exported_data.csv')
# Out:
# /Users/anhminhnguyen/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (40,41,43,45,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # Construction Lead Dust Complaints

# %%
filter_leaddust = df1['complaint_type'].str.contains('Construction Lead', na = False)

df1 = df1.loc[filter_leaddust]

df1
# Out:
#                 unique_key             created_date agency  \
# 3019      3019    54066546  2022-05-02T15:40:28.000  DOHMH
# 4474      4474    54063526  2022-05-02T12:03:33.000  DOHMH
# 6334      6334    54068599  2022-05-02T08:35:19.000  DOHMH
# 18649    18649    54050449  2022-04-30T18:47:23.000  DOHMH
# 22485    22485    54050448  2022-04-30T07:06:46.000  DOHMH
# ...        ...         ...                      ...    ...
# 974092  974092    52913713  2021-12-28T13:32:24.000  DOHMH
# 974135  974135    52908548  2021-12-28T13:26:07.000  DOHMH
# 976745  976745    52909717  2021-12-28T05:58:12.000  DOHMH
# 980835  980835    52901742  2021-12-27T12:28:54.000  DOHMH
# 986714  986714    52897355  2021-12-26T11:18:53.000  DOHMH
#
#                                     agency_name          complaint_type  \
# 3019    Department of Health and Mental Hygiene  Construction Lead Dust
# 4474    Department of Health and Mental Hygiene  Construction Lead Dust
# ...

# %% [markdown]
# #### Filter base on Lower East and Harlem zip

# %%
df1_filter_zip = df1[df1['incident_zip'].isin([10002, 10007, 10009, 10013, 10038, 10278, 10026, 10027, 10037, 10030, 10039, 10031, 10032, 10035])]

df1_filter_zip
# Out:
#                 unique_key             created_date agency  \
# 42829    42829    54027141  2022-04-27T15:55:35.000  DOHMH
# 46616    46616    54025011  2022-04-27T07:52:54.000  DOHMH
# 53886    53886    54016651  2022-04-26T08:52:36.000  DOHMH
# 99883    99883    53959786  2022-04-20T12:05:05.000  DOHMH
# 117416  117416    53943022  2022-04-18T09:52:48.000  DOHMH
# 181669  181669    53876832  2022-04-09T17:19:24.000  DOHMH
# 191487  191487    53863644  2022-04-08T13:42:52.000  DOHMH
# 201718  201718    53853934  2022-04-07T09:53:29.000  DOHMH
# 210309  210309    53844205  2022-04-06T08:34:36.000  DOHMH
# 266364  266364    53781576  2022-03-29T21:31:23.000  DOHMH
# 282011  282011    53768994  2022-03-28T09:32:33.000  DOHMH
# 293273  293273    53754778  2022-03-26T16:57:30.000  DOHMH
# 356887  356887    53683791  2022-03-18T13:50:03.000  DOHMH
# 357911  357911    53686261  2022-03-18T11:53:00.000  DOHMH
# 358630  358630    53679033  2022-03-18T10:31:27.000  DOHMH
# ...

# %% [markdown]
# #### Save filtered data: lead dust complaints

# %%
df1.to_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/Data/lead_construction_complaints_citywide.csv')

df1_filter_zip.to_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/Data/lead_construction_complaints_zipcodes.csv')

# %% [markdown]
# # Lead Kit Request

# %%
filter_leadkit = df['descriptor'].str.contains('Lead Kit Request', na = False)

df2 = df.loc[filter_leadkit]

df2
# Out:
#        unique_key             created_date agency  \
# 373      54066717  2022-05-02T23:40:00.000    DEP
# 518      54063716  2022-05-02T23:10:00.000    DEP
# 717      54061689  2022-05-02T22:37:00.000    DEP
# 1375     54066718  2022-05-02T20:35:00.000    DEP
# 2140     54068761  2022-05-02T18:08:00.000    DEP
# ...           ...                      ...    ...
# 996894   52886276  2021-12-24T05:01:00.000    DEP
# 997391   52882561  2021-12-24T00:42:00.000    DEP
# 998622   52879691  2021-12-23T20:14:00.000    DEP
# 999654   52875790  2021-12-23T16:36:00.000    DEP
# 999801   52880637  2021-12-23T16:09:00.000    DEP
#
#                                    agency_name complaint_type  \
# 373     Department of Environmental Protection           Lead
# 518     Department of Environmental Protection           Lead
# 717     Department of Environmental Protection           Lead
# 1375    Department of Environmental Protection           Lead
# ...

# %% [markdown]
# #### Save as csv Lead Kit Request

# %%
df2.to_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/Data/leadkit_request_citywide.csv')

# %%
df3 = pd.read_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/Data/leadkit_request_citywide.csv')

# %% [markdown]
# #### Filter base on Lower East and Harlem zip

# %%
df3_filter_zip = df3[df3['incident_zip'].isin([10002, 10007, 10009, 10013, 10038, 10278, 10026, 10027, 10037, 10030, 10039, 10031, 10032, 10035])]

df3_filter_zip
# Out:
#       Unnamed: 0  unique_key             created_date agency  \
# 4           2140    54068761  2022-05-02T18:08:00.000    DEP
# 34          8415    54056750  2022-05-01T22:55:00.000    DEP
# 42         12698    54059719  2022-05-01T12:52:00.000    DEP
# 47         13089    54054719  2022-05-01T11:31:00.000    DEP
# 56         21184    54048471  2022-04-30T11:36:00.000    DEP
# ...          ...         ...                      ...    ...
# 3401      967596    52914927  2021-12-29T14:19:00.000    DEP
# 3404      967981    52921199  2021-12-29T13:14:00.000    DEP
# 3425      970546    52918089  2021-12-29T03:34:00.000    DEP
# 3433      974056    52914506  2021-12-28T13:37:00.000    DEP
# 3439      975663    52906784  2021-12-28T09:58:00.000    DEP
#
#                                  agency_name complaint_type  \
# 4     Department of Environmental Protection           Lead
# 34    Department of Environmental Protection           Lead
# ...

# %%
df3_filter_zip.to_csv('/Users/anhminhnguyen/Documents/Data as Material/Neighborhood_Profile_WorkBook/Data/leadkit_request_zipcodes.csv')
