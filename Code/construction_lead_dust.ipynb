# %% [markdown]
# #### Pakages and Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Library from NYC OPEN API

# %%
from sodapy import Socrata

# %% [markdown]
# #### Request API

# %%
MyAppToken = "q1CBbdd2qgBeX7djvaE7muKIZ"
userame = "minhanh0604@gmail.com"
password = "R$@GzqVH5#RpWW6"

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofnewyork.us",
                  MyAppToken,
                  userame,
                  password,
                  timeout = 600)

# %%
# https://data.cityofnewyork.us/resource/erm2-nwe9.json

data_id = "erm2-nwe9"

# limit = number of first results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get(data_id, limit = 1000000, offset = 0)

# %%
# Convert to pandas DataFrame
df = pd.DataFrame.from_records(results)

# %%
df
# Out:
#        unique_key             created_date agency  \
# 0        54061329  2022-05-02T02:19:18.000    DOT
# 1        54054340  2022-05-02T02:18:06.000    DOT
# 2        54058396  2022-05-02T02:17:03.000    DOT
# 3        54057486  2022-05-02T02:05:43.000   NYPD
# 4        54060703  2022-05-02T02:05:36.000   NYPD
# ...           ...                      ...    ...
# 999995   52869113  2021-12-22T13:00:54.000    HPD
# 999996   52865952  2021-12-22T13:00:52.000    HPD
# 999997   52868952  2021-12-22T13:00:51.000    HPD
# 999998   52871013  2021-12-22T13:00:43.000    DOB
# 999999   52872058  2021-12-22T13:00:35.000   NYPD
#
#                                               agency_name  \
# 0                            Department of Transportation
# 1                            Department of Transportation
# 2                            Department of Transportation
# 3                         New York City Police Department
# 4                         New York City Police Department
# ...                                                   ...
# 999995  Department of Housing Preservation and Develop...
# 999996  Department of Housing Preservation and Develop...
# 999997  Department of Housing Preservation and Develop...
# 999998                            Department of Buildings
# 999999                    New York City Police Department
#
#               complaint_type  \
# 0           Street Condition
# 1           Street Condition
# 2           Street Condition
# 3          Illegal Fireworks
# 4            Illegal Parking
# ...                      ...
# 999995  UNSANITARY CONDITION
# 999996        HEAT/HOT WATER
# 999997        HEAT/HOT WATER
# 999998              Elevator
# 999999    Noise - Commercial
#
#                                                descriptor incident_zip  \
# 0                                                 Pothole        11213
# 1                                                 Pothole        11225
# 2                                                 Pothole        11213
# 3                                                     N/A        11372
# 4                                       Blocked Crosswalk        11103
# ...                                                   ...          ...
# 999995                          GARBAGE/RECYCLING STORAGE        10039
# 999996                                     APARTMENT ONLY        10025
# 999997                                     APARTMENT ONLY        11221
# 999998  Elevator - Single Device On Property/No Altern...        11229
# 999999                                   Banging/Pounding        10013
#
#              incident_address       street_name      cross_street_1  ...  \
# 0        839 EMPIRE BOULEVARD  EMPIRE BOULEVARD  SCHENECTADY AVENUE  ...
# 1            417 MAPLE STREET      MAPLE STREET         MIAMI COURT  ...
# 2           1669 UNION STREET      UNION STREET  SCHENECTADY AVENUE  ...
# 3                     37 ROAD           37 ROAD             37 ROAD  ...
# 4             44-03 31 AVENUE         31 AVENUE           44 STREET  ...
# ...                       ...               ...                 ...  ...
# 999995   269 WEST  154 STREET  WEST  154 STREET                 NaN  ...
# 999996   964 AMSTERDAM AVENUE  AMSTERDAM AVENUE                 NaN  ...
# 999997    715 BUSHWICK AVENUE   BUSHWICK AVENUE                 NaN  ...
# 999998  1745 EAST   12 STREET  EAST   12 STREET                 NaN  ...
# 999999         28 PELL STREET       PELL STREET       DOYERS STREET  ...
#
#            landmark bridge_highway_name road_ramp bridge_highway_segment  \
# 0               NaN                 NaN       NaN                    NaN
# 1               NaN                 NaN       NaN                    NaN
# 2               NaN                 NaN       NaN                    NaN
# 3               NaN                 NaN       NaN                    NaN
# 4         31 AVENUE                 NaN       NaN                    NaN
# ...             ...                 ...       ...                    ...
# 999995          NaN                 NaN       NaN                    NaN
# 999996          NaN                 NaN       NaN                    NaN
# 999997          NaN                 NaN       NaN                    NaN
# 999998          NaN                 NaN       NaN                    NaN
# 999999  PELL STREET                 NaN       NaN                    NaN
#
#                     closed_date taxi_pick_up_location  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# ...                         ...                   ...
# 999995                      NaN                   NaN
# 999996  2021-12-22T21:04:49.000                   NaN
# 999997  2021-12-27T11:00:11.000                   NaN
# 999998  2022-01-18T00:00:00.000                   NaN
# 999999  2021-12-22T13:45:20.000                   NaN
#
#        bridge_highway_direction due_date taxi_company_borough vehicle_type
# 0                           NaN      NaN                  NaN          NaN
# 1                           NaN      NaN                  NaN          NaN
# 2                           NaN      NaN                  NaN          NaN
# 3                           NaN      NaN                  NaN          NaN
# 4                           NaN      NaN                  NaN          NaN
# ...                         ...      ...                  ...          ...
# 999995                      NaN      NaN                  NaN          NaN
# 999996                      NaN      NaN                  NaN          NaN
# 999997                      NaN      NaN                  NaN          NaN
# 999998                      NaN      NaN                  NaN          NaN
# 999999                      NaN      NaN                  NaN          NaN
#
# [1000000 rows x 46 columns]

# %% [markdown]
# ### Create filter

# %%
filter = df['complaint_type'].str.contains('Construction Lead', na = False)
df.loc[filter]
# Out:
#        unique_key             created_date agency  \
# 11309    54050449  2022-04-30T18:47:23.000  DOHMH
# 15146    54050448  2022-04-30T07:06:46.000  DOHMH
# 18145    54041581  2022-04-29T20:11:50.000  DOHMH
# 22759    54037005  2022-04-29T09:36:35.000  DOHMH
# 28149    54032622  2022-04-28T14:27:43.000  DOHMH
# ...           ...                      ...    ...
# 973458   52901742  2021-12-27T12:28:54.000  DOHMH
# 979337   52897355  2021-12-26T11:18:53.000  DOHMH
# 993355   52873667  2021-12-23T13:34:00.000  DOHMH
# 994155   52877991  2021-12-23T11:44:25.000  DOHMH
# 999743   52867751  2021-12-22T13:44:57.000  DOHMH
#
#                                     agency_name          complaint_type  \
# 11309   Department of Health and Mental Hygiene  Construction Lead Dust
# 15146   Department of Health and Mental Hygiene  Construction Lead Dust
# 18145   Department of Health and Mental Hygiene  Construction Lead Dust
# 22759   Department of Health and Mental Hygiene  Construction Lead Dust
# 28149   Department of Health and Mental Hygiene  Construction Lead Dust
# ...                                         ...                     ...
# 973458  Department of Health and Mental Hygiene  Construction Lead Dust
# 979337  Department of Health and Mental Hygiene  Construction Lead Dust
# 993355  Department of Health and Mental Hygiene  Construction Lead Dust
# 994155  Department of Health and Mental Hygiene  Construction Lead Dust
# 999743  Department of Health and Mental Hygiene  Construction Lead Dust
#
#                         descriptor incident_zip       incident_address  \
# 11309              In Common Areas        10452  957 WOODYCREST AVENUE
# 15146              In Common Areas        10452  957 WOODYCREST AVENUE
# 18145        Coming into Apartment        10040      36 SHERMAN AVENUE
# 22759   Common Areas and Apartment        10014        63 PERRY STREET
# 28149              In Common Areas        11225   250 HAWTHORNE STREET
# ...                            ...          ...                    ...
# 973458       Coming into Apartment        11213   770 EMPIRE BOULEVARD
# 979337  Common Areas and Apartment        10460     1621 TAYLOR AVENUE
# 993355             In Common Areas        10003   334 EAST    9 STREET
# 994155             In Common Areas        11210     3103 FOSTER AVENUE
# 999743             In Common Areas        10024   205 WEST   80 STREET
#
#               street_name    cross_street_1  ...           landmark  \
# 11309   WOODYCREST AVENUE  WEST  162 STREET  ...  WOODYCREST AVENUE
# 15146   WOODYCREST AVENUE  WEST  162 STREET  ...  WOODYCREST AVENUE
# 18145      SHERMAN AVENUE    SICKLES STREET  ...     SHERMAN AVENUE
# 22759        PERRY STREET  WEST    4 STREET  ...       PERRY STREET
# 28149    HAWTHORNE STREET     ROGERS AVENUE  ...   HAWTHORNE STREET
# ...                   ...               ...  ...                ...
# 973458   EMPIRE BOULEVARD       TROY AVENUE  ...   EMPIRE BOULEVARD
# 979337      TAYLOR AVENUE          DEAD END  ...      TAYLOR AVENUE
# 993355   EAST    9 STREET          2 AVENUE  ...   EAST    9 STREET
# 994155      FOSTER AVENUE   NOSTRAND AVENUE  ...      FOSTER AVENUE
# 999743   WEST   80 STREET  AMSTERDAM AVENUE  ...   WEST   80 STREET
#
#        bridge_highway_name road_ramp bridge_highway_segment closed_date  \
# 11309                  NaN       NaN                    NaN         NaN
# 15146                  NaN       NaN                    NaN         NaN
# 18145                  NaN       NaN                    NaN         NaN
# 22759                  NaN       NaN                    NaN         NaN
# 28149                  NaN       NaN                    NaN         NaN
# ...                    ...       ...                    ...         ...
# 973458                 NaN       NaN                    NaN         NaN
# 979337                 NaN       NaN                    NaN         NaN
# 993355                 NaN       NaN                    NaN         NaN
# 994155                 NaN       NaN                    NaN         NaN
# 999743                 NaN       NaN                    NaN         NaN
#
#        taxi_pick_up_location bridge_highway_direction due_date  \
# 11309                    NaN                      NaN      NaN
# 15146                    NaN                      NaN      NaN
# 18145                    NaN                      NaN      NaN
# 22759                    NaN                      NaN      NaN
# 28149                    NaN                      NaN      NaN
# ...                      ...                      ...      ...
# 973458                   NaN                      NaN      NaN
# 979337                   NaN                      NaN      NaN
# 993355                   NaN                      NaN      NaN
# 994155                   NaN                      NaN      NaN
# 999743                   NaN                      NaN      NaN
#
#        taxi_company_borough vehicle_type
# 11309                   NaN          NaN
# 15146                   NaN          NaN
# 18145                   NaN          NaN
# 22759                   NaN          NaN
# 28149                   NaN          NaN
# ...                     ...          ...
# 973458                  NaN          NaN
# 979337                  NaN          NaN
# 993355                  NaN          NaN
# 994155                  NaN          NaN
# 999743                  NaN          NaN
#
# [281 rows x 46 columns]
